# %%
import os
import sys
import pandas as pd

# Add the data directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../data')))

# Import database credentials
from data_config import db_cred

# %%
def fetch_data_from_db(query):
    try:
        db = db_cred()  # Establish connection using db_cred
        cursor = db.cursor()
        
        # Execute the query
        cursor.execute(query)
        
        # Fetch all the data and column names
        rows = cursor.fetchall()
        column_names = [desc[0] for desc in cursor.description]  # Extract column names
        
        # Load into a DataFrame
        df = pd.DataFrame(rows, columns=column_names)
        
        # Close the cursor and database
        cursor.close()
        db.close()
        
        return df
    except Exception as e:
        print(f"Error: {e}")
        return None

# Query to fetch all data from the 'disease_data' table
query = "SELECT * FROM disease_data;"
data = fetch_data_from_db(query)

# Display the first few rows
if data is not None:
    print("Data fetched successfully!")
    display(data.head())
else:
    print("Failed to fetch data.")
# Out:
# Data fetched successfully!
#    id      Disease                                             Gender  \
# 0   1    Influenza  <phe.paillier.EncryptedNumber object at 0x73bf...
# 1   2  Common Cold  <phe.paillier.EncryptedNumber object at 0x73bf...
# 2   3       Eczema  <phe.paillier.EncryptedNumber object at 0x73bf...
# 3   4       Asthma  <phe.paillier.EncryptedNumber object at 0x73bf...
# 4   5       Asthma  <phe.paillier.EncryptedNumber object at 0x73bf...
#
#                                                Fever  \
# 0  <phe.paillier.EncryptedNumber object at 0x73bf...
# 1  <phe.paillier.EncryptedNumber object at 0x73bf...
# 2  <phe.paillier.EncryptedNumber object at 0x73bf...
# 3  <phe.paillier.EncryptedNumber object at 0x73bf...
# 4  <phe.paillier.EncryptedNumber object at 0x73bf...
#
#                                                Cough  \
# 0  <phe.paillier.EncryptedNumber object at 0x73bf...
# 1  <phe.paillier.EncryptedNumber object at 0x73bf...
# 2  <phe.paillier.EncryptedNumber object at 0x73bf...
# 3  <phe.paillier.EncryptedNumber object at 0x73bf...
# 4  <phe.paillier.EncryptedNumber object at 0x73bf...
#
#                                              Fatigue  \
# 0  <phe.paillier.EncryptedNumber object at 0x73bf...
# 1  <phe.paillier.EncryptedNumber object at 0x73bf...
# 2  <phe.paillier.EncryptedNumber object at 0x73bf...
# 3  <phe.paillier.EncryptedNumber object at 0x73bf...
# 4  <phe.paillier.EncryptedNumber object at 0x73bf...
#
#                                 Difficulty_Breathing  \
# 0  <phe.paillier.EncryptedNumber object at 0x73bf...
# 1  <phe.paillier.EncryptedNumber object at 0x73bf...
# 2  <phe.paillier.EncryptedNumber object at 0x73bf...
# 3  <phe.paillier.EncryptedNumber object at 0x73bf...
# 4  <phe.paillier.EncryptedNumber object at 0x73bf...
#
#                                                  Age  \
# 0  <phe.paillier.EncryptedNumber object at 0x73bf...
# 1  <phe.paillier.EncryptedNumber object at 0x73bf...
# 2  <phe.paillier.EncryptedNumber object at 0x73bf...
# 3  <phe.paillier.EncryptedNumber object at 0x73bf...
# 4  <phe.paillier.EncryptedNumber object at 0x73bf...
#
#                                       Blood_Pressure  \
# 0  <phe.paillier.EncryptedNumber object at 0x73bf...
# 1  <phe.paillier.EncryptedNumber object at 0x73bf...
# 2  <phe.paillier.EncryptedNumber object at 0x73bf...
# 3  <phe.paillier.EncryptedNumber object at 0x73bf...
# 4  <phe.paillier.EncryptedNumber object at 0x73bf...
#
#                                    Cholesterol_Level Outcome_Variable
# 0  <phe.paillier.EncryptedNumber object at 0x73bf...         Positive
# 1  <phe.paillier.EncryptedNumber object at 0x73bf...         Negative
# 2  <phe.paillier.EncryptedNumber object at 0x73bf...         Negative
# 3  <phe.paillier.EncryptedNumber object at 0x73bf...         Positive
# 4  <phe.paillier.EncryptedNumber object at 0x73bf...         Positive
